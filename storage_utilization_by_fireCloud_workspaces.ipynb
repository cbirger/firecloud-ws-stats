# %% [markdown]
# # Obtaining Storage Statistics For all of Workspaces Associated with a single FireCloud Billing Project

# %%
import json
import os
import csv
import subprocess
from fisswrapper.workspace_functions import list_workspaces
from fisswrapper.workspace_functions import get_workspace_info
import pandas as pd

# %%
project = "broad-firecloud-testing"
outputFile = "broad-firecloud-testing.tsv"
tmpFile = "tmp.txt"

# %%
workspaceList = list_workspaces(project=project)

# %%
with open(outputFile, 'w') as out:
    for workspaceListEntry in workspaceList:
        entryFields = workspaceListEntry.split(sep='\t')
        project = entryFields[0]
        workspace = entryFields[1]
        workspaceInfo = json.loads(get_workspace_info(project, workspace))
        owners = workspaceInfo['owners']
        bucketName = workspaceInfo['workspace']['bucketName'] 
        out.write("{0}\t{1}\t{2}\n".format(workspace, owners, bucketName))

# %% [markdown]
# # IMPORTANT!
# Before going further, execute the get_bucket_sizes.sh script, which will create a tmp.txt file with file sizes.  I'm doing it this way because I was having trouble running gsutil from within my python notebook.  The bash script creates a list of bucket sizes, one integer per line in the file tmp.txt.  The nth line in tmp.txt corresponds to the nth line in the broad-firecloud-testing.tsv file.

# %% [markdown]
# In the following cell we combine the contents of broad-firecloud-testing.tsv and tmp.txt into a list object, and then create a pandas data frame from that list.

# %%
combinedTable = []
with open(outputFile) as tsvfile, open(tmpFile) as tmpfile:
    reader1 = csv.reader(tsvfile, delimiter='\t')
    reader2 = csv.reader(tmpfile, delimiter='\t')
    for row1, row2 in zip(reader1, reader2):
        combinedTable.append(row1+row2)
labels = ['workspace_name', 'workspace_owners', 'workspace_bucket', 'bucket_size']
myDataFrame = pd.DataFrame.from_records(combinedTable,columns=labels)
# need to change the bucket_size column data from strong to numeric
myDataFrame[['bucket_size']] = myDataFrame[['bucket_size']].apply(pd.to_numeric)

# %%
myDataFrame.sort_values(by=['bucket_size'], ascending=False, inplace=True)

# %%
myDataFrame
# Out:
#                                         workspace_name  \
# 228                                         REBC_Oct16
# 59   Broad_MutationCalling_QC_Workflow_V1_BestPract...
# 194                                        PanCan_Full
# 4                                           ACC_PanCan
# 229                          REBC_Oct16_test_splitting
# 97                                            Dev_GINC
# 268          TCGA_UCS_ControlledAccess_V1-0_DATA_PCAWG
# 94                                        deTiN_public
# 168                                      MEETING_10_25
# 293                                  THCA_filtering_ws
# 117                                    EPACTS_analysis
# 227                              REBC_ACNV_eddie_clone
# 183                            new_bp_ws_clone_test_cc
# 95                                  deTiN_release_data
# 150                           gtex_test_0916_chet_0922
# 199                                     pcawg-WGS-test
# 259         TCGA_ControlledAccess_V1-0_DATA_polysolver
# 114                                 eddie_somatic_test
# 196                                      PanCan_Review
# 60   Broad_MutationCalling_QC_Workflow_V1_BestPract...
# 93                                      DeTiN_PanCan_2
# 52   Broad_MutationCalling_Mutect_Workflow_BestPrac...
# 235                                         RNA_MUTECT
# 193                            PANCAN_ANNOTS_TEST_copy
# 261                       TCGA_LIHC_Image_and_clinical
# 30     Broad_GTEx_RNASeq_Workflows_BestPractice-Test-6
# 0                          10-21-16-MuTect-Filter-test
# 34   Broad_GTEx_RNASeq_Workflows_BestPractice-testi...
# 195                                PanCan_Full_TESTING
# 125                                     filtering_test
# ..                                                 ...
# 239                       samtoolsindex_upscale5-test2
# 238              samtoolsindex_upscale5-test-11-29-Set
# 13                                    asdfasdfasdfadsf
# 234                                      revcomp_clone
# 232                                     REBC_WGS_PILOT
# 230                            rebc_template_copy_copy
# 14                                     aug22_test_chet
# 15                                              Backup
# 222                                    quick_test_Chet
# 220                          qc_somatic_acnv_filtering
# 213                                    qc-m-cn-test-DL
# 211                       Production_Analysis_Getz_Lab
# 207                    pmi-cohort-20k-diabetes-withbmi
# 206                            pmi-cohort-20k-diabetes
# 205                              pmi-cohort-20k-backup
# 203                         PCAWG_Review_only_with_maf
# 198                                      pcawg-WGS-CGA
# 197                                PCAWG-Docker-Test-2
# 187                                 no_normal_template
# 186                                        NIH_Testrun
# 48   Broad_MutationCalling_Mutect_Workflow_BestPrac...
# 181                                 MuTect-Test-Open-1
# 180  MutationCalling_QC-Mutect-CN_Workflow_BestPrac...
# 176     MiniMutationCalling_V1_Tutorial_eddie_20160601
# 173  MiniMutationCalling_V1_Tutorial_birger_17May_e...
# 185                                        NIH_TESTING
# 104                                   eddie_clust_play
# 129                          filtering_test_ca_new_dm1
# 188                                               NoGo
# 258    TCGA_COAD_ControlledAccess_V1-0_DATA_polysolver
#
#                                       workspace_owners  \
# 228  ['stewart@broadinstitute.org', 'mhanna@broadin...
# 59   ['mhanna@broadinstitute.org', 'esalinas@broadi...
# 194  ['igleshch@broadinstitute.org', 'danielr@broad...
# 4    ['danielr@broadinstitute.org', 'dlivitz@broadi...
# 229                    ['esalinas@broadinstitute.org']
# 97                      ['dlivitz@broadinstitute.org']
# 268  ['birger@broadinstitute.org', 'mhanna@broadins...
# 94                        ['amaro@broadinstitute.org']
# 168  ['mhanna@broadinstitute.org', 'stewart@broadin...
# 293  ['birger@broadinstitute.org', 'stewart@broadin...
# 117  ['gtiao@broadinstitute.org', 'esalinas@broadin...
# 227  ['stewart@broadinstitute.org', 'esalinas@broad...
# 183  ['stewart@broadinstitute.org', 'esalinas@broad...
# 95   ['amaro@broadinstitute.org', 'abaumann@broadin...
# 150                      ['birger@broadinstitute.org']
# 199                    ['mleventh@broadinstitute.org']
# 259  ['gsaksena@broadinstitute.org', 'esalinas@broa...
# 114                    ['esalinas@broadinstitute.org']
# 196  ['igleshch@broadinstitute.org', 'danielr@broad...
# 60   ['abaumann@broadinstitute.org', 'stewart@broad...
# 93                        ['amaro@broadinstitute.org']
# 52   ['birger@broadinstitute.org', 'mhanna@broadins...
# 235  ['rmunshi@broadinstitute.org', 'rfrazer@broadi...
# 193  ['danielr@broadinstitute.org', 'dlivitz@broadi...
# 261                      ['birger@broadinstitute.org']
# 30   ['francois@broadinstitute.org', 'jneff@broadin...
# 0    ['birger@broadinstitute.org', 'mhanna@broadins...
# 34   ['mhanna@broadinstitute.org', 'marfirecloud@gm...
# 195                     ['danielr@broadinstitute.org']
# 125  ['mhanna@broadinstitute.org', 'dlivitz@broadin...
# ..                                                 ...
# 239                       ['jneff@broadinstitute.org']
# 238                       ['jneff@broadinstitute.org']
# 13                    ['abaumann.firecloud@gmail.com']
# 234                    ['esalinas@broadinstitute.org']
# 232  ['stewart@broadinstitute.org', 'stjchanock@gma...
# 230  ['dlivitz@broadinstitute.org', 'GROUP_cga_het@...
# 14                       ['birger@broadinstitute.org']
# 15                      ['danielr@broadinstitute.org']
# 222                      ['birger@broadinstitute.org']
# 220                    ['esalinas@broadinstitute.org']
# 213  ['dlivitz@broadinstitute.org', 'esalinas@broad...
# 211                    ['igleshch@broadinstitute.org']
# 207                    ['dsiedzik@broadinstitute.org']
# 206                    ['dsiedzik@broadinstitute.org']
# 205                    ['dsiedzik@broadinstitute.org']
# 203  ['dlivitz@broadinstitute.org', 'igleshch@broad...
# 198                      ['mhanna@broadinstitute.org']
# 197                       ['jneff@broadinstitute.org']
# 187                     ['dlivitz@broadinstitute.org']
# 186                     ['danielr@broadinstitute.org']
# 48                     ['esalinas@broadinstitute.org']
# 181                       ['jneff@broadinstitute.org']
# 180                      ['mhanna@broadinstitute.org']
# 176                    ['esalinas@broadinstitute.org']
# 173                    ['esalinas@broadinstitute.org']
# 185                     ['danielr@broadinstitute.org']
# 104                    ['esalinas@broadinstitute.org']
# 129                    ['esalinas@broadinstitute.org']
# 188                    ['esalinas@broadinstitute.org']
# 258  ['esalinas@broadinstitute.org', 'sachet.shukla...
#
#                             workspace_bucket   bucket_size
# 228  fc-4520e968-446a-4f9f-85e2-8fcc901269dc  2.949855e+14
# 59   fc-01a0364e-80b5-4f9e-b787-61c66a79f720  8.452215e+12
# 194  fc-ca949d54-dc6f-41c9-b698-117650bf779a  3.637411e+12
# 4    fc-67d97596-903e-4405-83b3-ec258265962e  2.660387e+12
# 229  fc-36f0435a-17fe-4ec4-859d-7043230509ca  2.469926e+12
# 97   fc-1c01ba44-d1d4-470f-b4af-11fc8eb0532f  1.447478e+12
# 268  fc-b9a868f5-8c40-4252-b119-cf23ac1d8a2c  1.290774e+12
# 94   fc-97c909e0-8389-4238-beeb-32693b59b846  1.079730e+12
# 168  fc-75b01897-978e-4a63-9695-f82cf28ccb2d  1.009873e+12
# 293  fc-bea5e26a-be4e-4c95-afac-8c0ccb4cb083  8.729051e+11
# 117  fc-ce8cd6ac-b79f-4fb6-b4c8-1b521e9c4a7a  7.449713e+11
# 227  fc-7ac504fc-7fe4-4bc1-89d3-7f16317b8ff4  7.206946e+11
# 183  fc-ddba8b15-5812-44b9-9e2d-4cae75b110b0  7.000428e+11
# 95   fc-070aec01-a599-4fe3-9ed0-2f39288f912e  5.812112e+11
# 150  fc-babb50c8-9982-4f9a-aaac-7f4c8db15e12  3.334937e+11
# 199  fc-f3cdaf87-b243-4cfc-a464-b14b315fa8a9  3.261365e+11
# 259  fc-808c7bf6-8570-4c68-aa90-10265c3007b5  2.300578e+11
# 114  fc-656c7855-35b5-45a0-87ef-97a6c6587a34  2.279062e+11
# 196  fc-c1a3bbab-5277-4030-a504-b3244617c799  1.686205e+11
# 60   fc-ecb53f8c-26e3-4b8d-b2ee-f89bd6c77a40  1.523977e+11
# 93   fc-c14ae557-ab7f-4e8b-9a5b-63d2aee7e2c0  1.221602e+11
# 52   fc-df10949e-94dd-4330-b472-5370f95c037c  1.188223e+11
# 235  fc-48b23f20-a0a4-4576-914d-9e347b53f58a  1.153017e+11
# 193  fc-edaf8dab-5c4f-408d-91e2-ec9b76907351  1.029114e+11
# 261  fc-f9e5d77e-6ec6-4027-a956-475165e6248f  9.962358e+10
# 30   fc-b754dfa9-c5ac-466d-9e3a-b71e49cc7c1e  6.364470e+10
# 0    fc-f397dce5-57b9-4f94-8663-192b0be553da  5.897558e+10
# 34   fc-0870e845-4622-4804-ab34-69ac4a42e5e4  5.186703e+10
# 195  fc-b11b9f82-e32a-4be9-9f1a-ad2306d5af3b  5.115128e+10
# 125  fc-c844e9df-68d9-4814-84b7-72a6ceb649a1  4.953915e+10
# ..                                       ...           ...
# 239  fc-3df48369-d1cc-4f9a-a052-f9ffe1ae4f83  0.000000e+00
# 238  fc-1ce92681-9394-4941-9a84-f341ee8ab072  0.000000e+00
# 13   fc-e413e5dc-1946-4c26-89da-4a8ca66d3782  0.000000e+00
# 234  fc-99651626-9803-42bf-9e3f-38fb26e169a3  0.000000e+00
# 232  fc-5bfc3204-888c-4fa5-8905-4902954ce302  0.000000e+00
# 230  fc-3042ea3d-e5dc-4aee-9f36-bc535b3d9f02  0.000000e+00
# 14   fc-ec42c0a1-55f3-40c0-8150-c9916798251b  0.000000e+00
# 15   fc-0d85c0a7-d92c-48d6-b357-1a61c86a7c46  0.000000e+00
# 222  fc-0a296f0c-6573-4c9f-a07b-2f3934f62ee6  0.000000e+00
# 220  fc-f68cd160-994a-4d54-aa3a-b17d9215b5dd  0.000000e+00
# 213  fc-5dbb3350-ffbd-4b69-b18a-dc6cd43601fa  0.000000e+00
# 211  fc-5019f4ae-1f71-429f-bbf4-7cee4562d2f3  0.000000e+00
# 207  fc-176559cb-6f65-49c1-9dc1-f6bb98c5dee7  0.000000e+00
# 206  fc-42810262-7a13-472d-bf55-87b5aa3a01fd  0.000000e+00
# 205  fc-8e7b0d72-4b24-4e25-b0b4-92decec9da46  0.000000e+00
# 203  fc-ea39b9f2-5aa9-4d58-be55-0c5646a5c5e5  0.000000e+00
# 198  fc-aeed3ae3-982b-444a-afdf-4cc4406803ab  0.000000e+00
# 197  fc-829e8a1a-295e-4ae1-8262-bcac5087e412  0.000000e+00
# 187  fc-2b75f27b-995a-4e7b-b699-b1b21984e9b1  0.000000e+00
# 186  fc-217e9740-ef04-4765-b237-98ac522a12f6  0.000000e+00
# 48   fc-d9798fc9-6ea6-423e-879c-d5d96be61a57  0.000000e+00
# 181  fc-8c96443d-10d6-458f-ba46-6f2d7e9d3315  0.000000e+00
# 180  fc-4d7182d0-97be-4843-9c92-774b8f9b92da  0.000000e+00
# 176  fc-ce7c2d09-8ccb-4366-a0b0-ccb6398fc6f8  0.000000e+00
# 173  fc-bdde0e80-6f23-4e8a-9e87-1f5c290b0afd  0.000000e+00
# 185  fc-d8cec039-0537-40e5-9a37-b907a77da579  0.000000e+00
# 104  fc-1438038f-ba15-483f-b55a-7ced8334d94f           NaN
# 129  fc-4857483d-ff87-4bc9-b8b4-830c7b956f69           NaN
# 188  fc-d72a1424-ab62-4496-8c6f-32b6338f33a9           NaN
# 258  fc-6df63763-a23e-4c5f-a9d6-c24e650f3dee           NaN
#
# [321 rows x 4 columns]

# %% [markdown]
# Now write sorted dataframe as a TSV file.

# %%
finalFilename = 'broad-firecloud-testing-complete.tsv'
myDataFrame.to_csv(finalFilename,sep='\t')
